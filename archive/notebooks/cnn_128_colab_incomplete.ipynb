# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
import math
from tensorflow.keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/Processed_asl_alphabet.zip -d /content/Datasets
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P783.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P783.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2683.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2683.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P797.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P797.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1163.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1163.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1605.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1605.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P27.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P27.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P218.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P218.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P33.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P33.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2318.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2318.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1611.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1611.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1177.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1177.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P542.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P542.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2456.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2456.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2330.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2330.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P224.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P224.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1639.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1639.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2324.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2324.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P230.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P230.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P556.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P556.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2442.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2442.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P581.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P581.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2495.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2495.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1822.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1822.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1836.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1836.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1188.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1188.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P595.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P595.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2481.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2481.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1837.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1837.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2480.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2480.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P594.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P594.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1189.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1189.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2494.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2494.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P580.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P580.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1823.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1823.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P231.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P231.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2325.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2325.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2443.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2443.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P557.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P557.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2457.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2457.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P543.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P543.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1638.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1638.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P225.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P225.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2331.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2331.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1610.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1610.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2319.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2319.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P32.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P32.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1176.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1176.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1162.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1162.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P219.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P219.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P26.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P26.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1604.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1604.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P796.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P796.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2682.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2682.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P782.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P782.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2696.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2696.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P972.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P972.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2866.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2866.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P966.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P966.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2872.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2872.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P755.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P755.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2641.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2641.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2899.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2899.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1348.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1348.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2127.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2127.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2133.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2133.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P741.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P741.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2655.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2655.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P999.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P999.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1374.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1374.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P769.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P769.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1412.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1412.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1406.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1406.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2669.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2669.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1360.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1360.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P184.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P184.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2090.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2090.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1599.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1599.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P190.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P190.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2084.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2084.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2912.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2912.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P806.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P806.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2906.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2906.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P812.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P812.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2735.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2735.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P621.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P621.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P147.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P147.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2053.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2053.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P153.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P153.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2047.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2047.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1228.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1228.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2721.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2721.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P635.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P635.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1200.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1200.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2709.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2709.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1566.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1566.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1572.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1572.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P609.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P609.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1214.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1214.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P1943.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P1943.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/P/P2292.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/P/._P2292.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W344.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W344.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2966.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2966.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W422.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W422.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2972.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2972.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W436.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W436.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W350.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W350.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W378.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W378.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2782.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2782.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2796.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2796.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W387.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W387.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1512.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1512.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1274.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1274.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2769.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2769.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1260.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1260.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1506.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1506.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W393.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W393.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2027.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2027.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2741.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2741.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2999.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2999.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1248.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1248.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2755.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2755.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2033.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2033.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W620.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W620.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W146.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W146.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W152.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W152.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W634.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W634.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2580.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2580.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1089.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1089.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1937.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1937.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1923.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1923.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2594.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2594.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W608.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W608.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1076.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1076.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1710.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1710.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2219.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2219.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W185.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W185.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W191.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W191.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1704.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1704.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1062.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1062.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W807.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W807.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2543.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2543.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2225.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2225.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1738.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1738.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2231.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2231.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W813.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W813.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2557.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2557.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W754.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W754.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W740.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W740.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W998.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W998.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W768.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W768.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1843.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1843.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2392.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2392.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2386.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2386.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1857.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1857.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W797.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W797.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1102.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1102.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1664.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1664.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2379.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2379.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1670.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1670.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1116.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1116.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W783.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W783.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2437.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2437.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W973.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W973.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2351.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2351.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1658.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1658.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1880.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1880.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1894.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1894.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2345.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2345.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2423.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2423.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W967.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W967.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W230.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W230.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W60.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W60.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W556.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W556.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2812.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2812.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W542.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W542.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2806.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2806.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W224.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W224.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W74.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W74.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2190.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2190.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1499.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1499.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W218.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W218.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2184.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2184.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W48.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W48.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1466.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1466.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1300.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1300.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W595.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W595.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2609.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2609.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W581.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W581.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1314.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1314.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1472.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1472.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2153.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2153.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2635.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2635.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1328.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1328.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2621.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2621.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2147.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2147.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2620.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2620.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1329.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1329.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2146.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2146.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2152.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2152.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2634.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2634.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1315.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1315.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W580.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W580.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1473.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1473.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1467.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1467.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2608.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2608.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W594.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W594.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1301.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1301.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2185.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2185.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W49.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W49.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W219.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W219.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1498.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1498.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2191.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2191.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2807.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2807.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W543.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W543.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W75.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W75.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W225.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W225.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W61.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W61.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W231.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W231.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2813.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2813.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W557.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W557.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2344.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2344.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1895.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1895.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W966.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W966.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2422.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2422.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W972.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W972.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2436.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2436.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1881.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1881.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1659.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1659.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2350.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2350.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1671.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1671.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2378.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2378.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W782.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W782.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1117.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1117.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1103.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1103.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W796.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W796.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1665.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1665.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1856.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1856.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2387.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2387.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W769.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W769.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2393.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2393.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1842.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1842.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W999.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W999.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W741.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W741.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W755.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W755.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2230.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2230.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1739.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1739.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2556.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2556.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W812.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W812.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2542.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2542.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W806.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W806.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2224.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2224.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1705.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1705.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W190.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W190.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1063.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1063.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1077.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1077.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W184.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W184.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2218.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2218.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1711.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1711.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1922.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1922.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W609.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W609.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2595.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2595.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1088.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1088.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2581.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2581.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1936.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1936.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W153.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W153.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W635.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W635.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W621.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W621.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W147.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W147.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2754.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2754.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2032.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2032.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2026.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2026.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1249.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1249.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2998.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2998.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2740.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2740.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1261.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1261.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2768.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2768.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W392.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W392.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1507.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1507.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1513.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1513.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W386.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W386.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1275.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1275.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2797.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2797.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W379.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W379.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2783.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2783.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W437.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W437.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2973.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2973.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W351.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W351.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W345.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W345.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W423.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W423.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2967.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2967.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W353.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W353.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2971.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2971.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W435.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W435.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2965.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2965.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W421.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W421.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W347.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W347.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W409.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W409.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2795.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2795.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1288.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1288.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2959.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2959.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2781.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2781.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1505.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1505.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W390.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W390.jpg
# ...
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1123.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1123.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1645.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1645.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1651.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1651.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1889.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1889.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2358.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2358.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1137.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1137.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2416.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2416.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W952.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W952.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1679.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1679.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2370.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2370.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2364.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2364.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2402.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2402.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W946.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W946.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W211.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W211.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W41.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W41.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1484.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1484.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W577.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W577.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2833.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2833.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W563.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W563.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2827.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2827.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1490.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1490.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W205.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W205.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W55.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W55.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2199.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2199.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W239.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W239.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W69.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W69.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1447.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1447.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W82.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W82.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2628.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2628.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1321.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1321.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1335.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1335.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W96.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W96.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1453.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1453.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2172.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2172.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W588.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W588.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2614.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2614.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2600.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2600.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1309.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1309.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2166.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2166.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1308.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1308.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2601.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2601.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2167.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2167.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2173.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2173.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2615.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2615.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W589.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W589.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1334.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1334.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1452.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1452.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W97.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W97.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W83.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W83.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1446.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1446.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1320.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1320.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2629.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2629.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W68.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W68.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W238.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W238.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2826.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2826.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W562.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W562.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W54.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W54.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2198.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2198.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W204.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W204.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1491.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1491.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1485.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1485.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W40.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W40.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W210.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W210.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2832.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2832.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W576.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W576.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2365.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2365.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W947.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W947.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2403.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2403.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W953.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W953.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2417.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2417.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2371.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2371.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1678.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1678.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2359.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2359.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1888.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1888.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1650.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1650.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1136.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1136.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1122.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1122.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1644.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1644.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1877.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1877.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W984.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W984.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W990.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W990.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W748.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W748.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1863.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1863.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1693.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1693.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W760.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W760.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W774.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W774.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1687.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1687.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1718.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1718.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2211.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2211.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2577.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2577.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W833.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W833.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W5.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W5.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2563.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2563.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W827.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W827.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W199.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W199.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2205.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2205.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1724.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1724.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1042.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1042.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1056.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1056.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W1730.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W1730.jpg
#   inflating: /content/Datasets/Processed_asl_alphabet/train/W/W2239.jpg
#   inflating: /content/Datasets/__MACOSX/Processed_asl_alphabet/train/W/._W2239.jpg

# %%
# Paths to training and test data
train_dir = "/content/Datasets/Processed_asl_alphabet/train"
test_dir = "/content/Datasets/Processed_asl_alphabet/test"
# train_dir = "../Datasets/Processed_asl_alphabet/train"
# test_dir = "../Datasets/Processed_asl_alphabet/test"

# Image dimensions
IMG_HEIGHT, IMG_WIDTH = 128, 128

# Preprocessing and augmentation for training set
train_datagen = ImageDataGenerator(
    rescale=1.0 / 255,               # Normalize pixel values
    rotation_range=20,               # Data augmentation
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2             # Train-validation split
)

# Preprocessing for validation and test sets (no augmentation)
test_val_datagen = ImageDataGenerator(rescale=1.0 / 255)

# %%
# Load training and validation data
train_data = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_data = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)

# Load test data
test_data = test_val_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# Print class indices
print("Class indices:", train_data.class_indices)
# train_steps_per_epoch = math.ceil(49920 / batch_size)
# val_steps_per_epoch = math.ceil(val_samples / batch_size)

# print(f"Steps per Epoch (Training): {train_steps_per_epoch}")
# print(f"Steps per Epoch (Validation): {val_steps_per_epoch}")
# Out:
# Found 49920 images belonging to 26 classes.
# Found 12480 images belonging to 26 classes.
# Found 15600 images belonging to 26 classes.
# Class indices: {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'I': 8, 'J': 9, 'K': 10, 'L': 11, 'M': 12, 'N': 13, 'O': 14, 'P': 15, 'Q': 16, 'R': 17, 'S': 18, 'T': 19, 'U': 20, 'V': 21, 'W': 22, 'X': 23, 'Y': 24, 'Z': 25}

# %%
# Generate and visualize augmented images
def show_augmented_images(data_generator, class_name, num_images=5):
    # Find a batch of images for the specific class
    for batch, labels in data_generator:
        # Find the index of the requested class
        class_index = list(data_generator.class_indices.keys()).index(class_name)
        indices = [i for i, label in enumerate(labels) if label[class_index] == 1]

        # Break if enough images are found
        if len(indices) >= num_images:
            break

    # Display augmented images
    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(indices[:num_images]):
        img = batch[idx]
        plt.subplot(1, num_images, i + 1)
        plt.imshow(img)
        plt.title(class_name)
        plt.axis("off")
    plt.tight_layout()
    plt.show()

# Example: Display augmented images for the class "A"
show_augmented_images(train_data, "A")

# %%
# Wrapping the DirectoryIterator into a tf.data.Dataset
def make_repeating_dataset(data_iterator):
    dataset = tf.data.Dataset.from_generator(
        lambda: data_iterator,
        output_signature=(
            tf.TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32),
            tf.TensorSpec(shape=(None, len(data_iterator.class_indices)), dtype=tf.float32)
        )
    )
    return dataset.repeat()

# Create repeating datasets
train_dataset = make_repeating_dataset(train_data)
val_dataset = make_repeating_dataset(val_data)

# %%
# Define the CNN model
def create_cnn_model(input_shape, num_classes):
    model = Sequential([
        # Convolutional layers
        Conv2D(64, (3, 3), padding='same', activation='relu', input_shape=input_shape),
        MaxPooling2D((2, 2)),
        BatchNormalization(),

        Conv2D(128, (3, 3), padding='same', activation='relu'),
        MaxPooling2D((2, 2)),
        BatchNormalization(),
        Dropout(0.2),

        Conv2D(256, (3, 3), padding='same', activation='relu'),
        MaxPooling2D((2, 2)),
        BatchNormalization(),

        # Flatten the output
        Flatten(),
        Dropout(0.2),
        # Fully connected layers
        Dense(1024, activation='relu'),
        Dropout(0.2),
        Dense(num_classes, activation='softmax')  # Output layer
    ])
    return model

# %%
# Model parameters
input_shape = (128, 128, 3)  # Image dimensions (H, W, Channels)
num_classes = len(train_data.class_indices)  # Number of classes
# adam = Adam(0.01)
# Create the model
model = create_cnn_model(input_shape, num_classes)

# Compile the model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Summary of the model
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)                    │ (None, 128, 128, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 64, 64, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 64, 64, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 32, 32, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 32, 32, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 32, 32, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 32, 32, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 16, 16, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 16, 16, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 65536)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 65536)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1024)                │      67,109,888 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 26)                  │          26,650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 67,509,146 (257.53 MB)
#  Trainable params: 67,508,250 (257.52 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

# Train the model
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=40,  # You can adjust this based on your dataset
    steps_per_epoch=train_data.samples // train_data.batch_size,
    validation_steps=val_data.samples // val_data.batch_size,
    callbacks=[early_stopping],
    shuffle=True,
    verbose=1
)

# Evaluate on the test set
test_loss, test_accuracy = model.evaluate(test_data)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Epoch 1/40
#  199/1560 ━━━━━━━━━━━━━━━━━━━━ 2:07:29 6s/step - accuracy: 0.0436 - loss: 8.9145

# %%
import matplotlib.pyplot as plt

def plot_accuracy_loss(history):
    # Accuracy plot
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Loss plot
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Call the function after training
plot_accuracy_loss(history)

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

def plot_confusion_matrix(model, test_data):
    # Get true labels and predictions
    true_labels = test_data.classes
    pred_probs = model.predict(test_data)
    pred_labels = np.argmax(pred_probs, axis=1)

    # Confusion matrix
    cm = confusion_matrix(true_labels, pred_labels)
    class_names = list(test_data.class_indices.keys())

    # Plot confusion matrix
    plt.figure(figsize=(12, 10))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.show()

    # Classification report
    print("\nClassification Report:\n")
    print(classification_report(true_labels, pred_labels, target_names=class_names))

# Call the function after training
plot_confusion_matrix(model, test_data)

# %%
def plot_predictions(model, test_data, num_images=9):
    # Get a batch of test data
    test_data.reset()  # Reset iterator to avoid issues
    images, labels = next(test_data)
    predictions = model.predict(images)

    # Plot predictions
    plt.figure(figsize=(15, 10))
    for i in range(num_images):
        plt.subplot(3, 3, i + 1)
        plt.imshow(images[i])
        true_label = list(test_data.class_indices.keys())[np.argmax(labels[i])]
        pred_label = list(test_data.class_indices.keys())[np.argmax(predictions[i])]
        confidence = np.max(predictions[i]) * 100
        plt.title(f"True: {true_label}\nPred: {pred_label} ({confidence:.2f}%)")
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# Call the function
plot_predictions(model, test_data)

# %%
import numpy as np

def plot_random_predictions(model, test_data, num_images=9):
    # Reset test data iterator and fetch all batches
    test_data.reset()
    all_images, all_labels = [], []
    for _ in range(len(test_data)):
        images, labels = next(test_data)
        all_images.append(images)
        all_labels.append(labels)

    # Concatenate all images and labels
    all_images = np.concatenate(all_images, axis=0)
    all_labels = np.concatenate(all_labels, axis=0)

    # Make predictions on all images
    predictions = model.predict(all_images)

    # Select random indices
    random_indices = np.random.choice(len(all_images), num_images, replace=False)

    # Plot predictions
    plt.figure(figsize=(15, 10))
    for i, idx in enumerate(random_indices):
        plt.subplot(3, 3, i + 1)
        plt.imshow(all_images[idx])
        true_label = list(test_data.class_indices.keys())[np.argmax(all_labels[idx])]
        pred_label = list(test_data.class_indices.keys())[np.argmax(predictions[idx])]
        confidence = np.max(predictions[idx]) * 100
        plt.title(f"True: {true_label}\nPred: {pred_label} ({confidence:.2f}%)")
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# Call the function
plot_random_predictions(model, test_data)

# %%
def plot_correct_and_incorrect_predictions(model, test_data, num_images=9):
    # Reset test data iterator and fetch all data
    test_data.reset()
    all_images, all_labels = [], []
    for _ in range(len(test_data)):
        images, labels = next(test_data)
        all_images.append(images)
        all_labels.append(labels)

    # Concatenate all images and labels
    all_images = np.concatenate(all_images, axis=0)
    all_labels = np.concatenate(all_labels, axis=0)

    # Make predictions
    predictions = model.predict(all_images)
    predicted_labels = np.argmax(predictions, axis=1)
    true_labels = np.argmax(all_labels, axis=1)

    # Separate correct and incorrect predictions
    correct_indices = [i for i in range(len(true_labels)) if predicted_labels[i] == true_labels[i]]
    incorrect_indices = [i for i in range(len(true_labels)) if predicted_labels[i] != true_labels[i]]

    # Helper function to plot images
    def plot_images(indices, title):
        plt.figure(figsize=(15, 10))
        for i, idx in enumerate(indices[:num_images]):
            plt.subplot(3, 3, i + 1)
            plt.imshow(all_images[idx])
            true_label = list(test_data.class_indices.keys())[true_labels[idx]]
            pred_label = list(test_data.class_indices.keys())[predicted_labels[idx]]
            confidence = np.max(predictions[idx]) * 100
            plt.title(f"True: {true_label}\nPred: {pred_label} ({confidence:.2f}%)")
            plt.axis('off')
        plt.suptitle(title, fontsize=16)
        plt.tight_layout()
        plt.show()

    # Plot correct predictions
    if correct_indices:
        plot_images(correct_indices, "Correct Predictions")
    else:
        print("No correct predictions found.")

    # Plot incorrect predictions
    if incorrect_indices:
        plot_images(incorrect_indices, "Incorrect Predictions")
    else:
        print("No incorrect predictions found.")

# Call the function
plot_correct_and_incorrect_predictions(model, test_data)
